# %% [markdown]
# # Welcome to 2021
# ![](pics/lets_build_robots.png)

# %% [markdown]
# ![](pics/35973186-refresh-red-glossy-round-button.jpg)

# %% [markdown]
# # Shutdown -- the Right Way

# %% [markdown]
# ![](pics/shutdown_pic.jpg)

# %% [markdown]
# # New Python Code Editor

# %% [markdown]
# ![](pics/vscode_pic.jpg)

# %% [markdown]
# ![](pics/python-logo-master-v3-TM.png)

# %% [markdown]
# ---
#
# ```python
# # Our team's simple test module
#
# from gpiozero import Robot
# import time
#
# robby = Robot(left=(7, 8), right=(9, 10))
#
# robby.forward()
# time.sleep(20)
# robby.stop()
# ```
#
# ---

# %% [markdown]
# # Thinking In Python (little-by-little)
#
# ---

# %% [markdown]
# ```python
# # Our team's simple test module
# ```

# %% [markdown]
# ```python
# a = 1 # this is also a comment
# ```

# %% [markdown]
# ```python
# '''
# this is also comment
# that fits on multiple
# lines
#
# :)
#
# a = 1
# '''
# ```

# %% [markdown]
# # Thinking In Python (little-by-little)
#
# ---

# %% [markdown]
# ```python
# # Our team's simple test module
# ```

# %% [markdown]
# ```python
# from gpiozero import Robot
# import time
# ```

# %% [markdown]
# ```python
# robby = Robot(left=(7, 8), right=(9, 10))
# ```

# %% [markdown]
# ```python
# robby.forward()
# ```

# %% [markdown]
# ```python
# time.sleep(20)
# ```

# %% [markdown]
# ```python
# robby.stop()
# ```
#
# ---

# %% [markdown]
# ![](pics/lets_build_great_things.png)
